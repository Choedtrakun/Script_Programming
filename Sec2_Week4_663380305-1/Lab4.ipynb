# %% [markdown]
# # lab4_1.py - Student Management System (List Operations)

# %%
# lab4_1.py - Student Management System (List Operations)
# หมายเหตุ: โค้ดนี้ตัดส่วน "Challenge" (ระบบเมนูแบบ while loop) ออก
#          เพื่อให้นักศึกษานำ concept ด้านล่างไปต่อยอดคิดเองเป็นแบบฝึกหัด

print("--- Lab 4.1: Student Management System ---")

# 1) เริ่มต้นด้วย list ว่างสำหรับเก็บชื่อนักศึกษา
student_names = []

# 2) เพิ่มนักศึกษา: รับชื่อจากผู้ใช้ 3 คน แล้ว append() เข้า list
print("\n[1] Add Students")
for i in range(3): #กำหนดตัวแปรใน loop 👈ต้องทำ
    name = input(f"Enter student name #{i + 1}: ") #กำหนดตัวแปร 👈ต้องทำ
    student_names.append(name)

print(f"Current list: {student_names}")

# 3) ค้นหานักศึกษา: ใช้ 'in' เพื่อเช็คว่ามีชื่อนี้อยู่ใน list หรือไม่
#    ถ้าพบ ให้แสดง index ด้วย index()
print("\n[2] Find a Student")
search_name = input("Enter a name to search for: ")

if search_name in student_names:#เขียนเงื่อนไข ถ้าหากมีชื่อในลิส: 👈ต้องทำ
    position = student_names.index(search_name)
    print(f"Found '{search_name}' at index {position}")
else:
    print(f"'{search_name}' not found in the list")

# 4) ลบนักศึกษา: เช็คก่อนว่ามีอยู่จริงหรือไม่ (กัน error) แล้วค่อย remove()
print("\n[3] Remove a Student")
remove_name = input("Enter a name to remove: ")

if remove_name in student_names:
    student_names.remove(remove_name) #เติมฟังก์ชัน remove(remove_name) 👈ต้องทำ
    print(f"'{remove_name}' has been removed")
else:
    print(f"'{remove_name}' not found, nothing removed")

print(f"Updated list: {student_names}")

# 5) เรียงลำดับรายชื่อตามตัวอักษรด้วย sort()
print("\n[4] Sort Students")
student_names = student_names.sort()
print(f"Sorted list: {student_names}")

# 6) นับจำนวนนักศึกษาทั้งหมดด้วย len()
print("\n[5] Count Students")
print(f"Total students: {len(student_names)}") #ใช้คำสั่งlen() หาจำนวนนักศึกษาในลิส student_names👈ต้องทำ

# --------------------------------------------------------------------
# ให้นักศึกษาลองต่อยอดเอง (Challenge):
# ลองเขียนระบบเมนูด้วย while loop (จาก Week 3) ที่ให้ผู้ใช้เลือกได้ว่า
# จะเพิ่ม / ลบ / ค้นหา / เรียงลำดับ / หรือออกจากโปรแกรม
# โดยนำโค้ดแต่ละส่วนด้านบนไปจัดเป็นฟังก์ชันหรือเงื่อนไขในเมนู
# --------------------------------------------------------------------

# %% [markdown]
# # **Lab4.1 Challenge**

# %%
# lab4_1.py - Challenge
def AddName():
    print("\n[1] Add Students")
    x = int(input("How many students do you want to add?"))
    for i in range(x):
        name = input(f"Enter student name #{i + 1}: ")
        student_names.append(name)
    
    print(f"Current list: {student_names}")

def RemoveName():
    print("\n[3] Remove a Student")
    remove_name = input("Enter a name to remove: ")

    if remove_name in student_names:
        student_names.remove(remove_name)
        print(f"'{remove_name}' has been removed")
    else:
        print(f"'{remove_name}' not found, nothing removed")

    print(f"Updated list: {student_names}")

def SearchName():
    print("\n[2] Find a Student")
    search_name = input("Enter a name to search for: ")

    if search_name in student_names:
        position = student_names.index(search_name)
        print(f"Found '{search_name}' at index {position}")
    else:
        print(f"'{search_name}' not found in the list")

def SortName():
    print("\n[4] Sort Students")
    student_names = student_names.sort()
    print(f"Sorted list: {student_names}")


print("--- Lab 4.1: Student Management System(Challenge) ---")
student_names = []

print("\n[1] Add Students\n[2] Remove Student\n[3] Find a Student\n[4] Sort Students\n[0] Exit")
while True:
    x = input("Please select an option (0-4): ")
    try:
        x = int(x)
        if x == 1:
            AddName()
        elif x == 2:
            RemoveName()
        elif x == 3:
            SearchName()
        elif x == 4:
            SortName()
        elif x == 0:
            print("\n--Count Students--")
            print(f"Total students: {len(student_names)}")
            break
    except:
        print("\nInvalid input. Please enter a number between 0 and 4.\n")
# Out:
# --- Lab 4.1: Student Management System(Challenge) ---
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
#
# [2] Find a Student
# 'ff' not found in the list
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
#
# [1] Add Students
# Invalid input. Please enter a number between 0 and 4.
#
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
# Invalid input. Please enter a number between 0 and 4.
#
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
# Invalid input. Please enter a number between 0 and 4.
#
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
#
# [1] Add Students
# Current list: ['qqq', 'www', 'eee', 'rrr']
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
#
# [2] Find a Student
# 'qqqqqq' not found in the list
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
#
# [2] Find a Student
# Found 'qqq' at index 0
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
#
# [4] Sort Students
# Sorted list: ['qqq', 'www', 'eee', 'rrr']
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
#
# [3] Remove a Student
# 'www' has been removed
# Updated list: ['qqq', 'eee', 'rrr']
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
#
# [1] Add Students
# Current list: ['qqq', 'eee', 'rrr', 'ddd']
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
#
# [4] Sort Students
# Sorted list: ['qqq', 'eee', 'rrr', 'ddd']
#
# [1] Add Students
# [2] Remove Student
# [3] Find a Student
# [4] Sort Students
# [0] Exit
#
# --Count Students--
# Total students: 4

# %% [markdown]
# # lab4_2.py - Geometric Calculations (Tuples & Immutability)

# %%
# lab4_2.py - Geometric Calculations (Tuples & Immutability)
# หมายเหตุ: โค้ดนี้ตัดส่วน "Challenge" (รับพิกัดจากผู้ใช้เพื่อคำนวณระยะทาง) ออก
#          เพื่อให้นักศึกษานำ concept ด้านล่างไปต่อยอดคิดเองเป็นแบบฝึกหัด

import math

print("--- Lab 4.2: Geometric Calculations ---")

# 1) กำหนดจุดสองจุดด้วย tuple: point1 และ point2
point1 = (2 , 1) #เติมพิกัด x y ของจุด 👈ต้องทำ
point2 = (0 , 0)  #เติมพิกัด x y ของจุด 👈ต้องทำ

# 2) เข้าถึงค่าพิกัด x, y ของแต่ละจุด
print("\n[1] Access Coordinates")
print(f"Point 1: x = {point1[0]}, y = {point1[1]}") #เติมเลข 0 และ 1 ใน [] 👈ต้องทำ
print(f"Point 2: x = {point2[0]}, y = {point2[1]}") #เติมเลข 0 และ 1 ใน [] 👈ต้องทำ

# 3) ทดลองแก้ไขค่าใน tuple เพื่อแสดงให้เห็นว่า tuple เปลี่ยนแปลงไม่ได้ (immutable)
print("\n[2] Attempt Modification (Immutability Demonstration)")
try:
    point1[0] = 5  # บรรทัดนี้จะทำให้เกิด TypeError เพราะ tuple แก้ไขไม่ได้
except TypeError as e:
    print(f"Error trying to modify tuple: {e}")

# 4) คำนวณระยะห่างระหว่างจุดสองจุดด้วยสูตรระยะทาง
#    distance = sqrt( (x2 - x1)^2 + (y2 - y1)^2 )
print("\n[3] Calculate Distance")
distance = math.sqrt((point2[0] - point1[0]) ** 2 + (point2[1] - point1[1]) ** 2) #เติมเลขตำแหน่งในลิส 0 และ 1 ใน [] ให้ถูกต้อง 👈ต้องทำ
print(f"Distance between point1 {point1} and point2 {point2}: {distance}")

# --------------------------------------------------------------------
# ให้นักศึกษาลองต่อยอดเอง (Challenge):
# ลองแก้โค้ดให้รับพิกัดของจุดใหม่ 2 จุดจากผู้ใช้ผ่าน input()
# (อย่าลืมแปลงชนิดข้อมูลจาก input() ให้เป็นตัวเลขก่อนนำไปคำนวณ)
# แล้วคำนวณระยะห่างระหว่างจุดทั้งสองที่ผู้ใช้กรอกเข้ามา
# --------------------------------------------------------------------
# Out:
# --- Lab 4.2: Geometric Calculations ---
#
# [1] Access Coordinates
# Point 1: x = 2, y = 1
# Point 2: x = 0, y = 0
#
# [2] Attempt Modification (Immutability Demonstration)
# Error trying to modify tuple: 'tuple' object does not support item assignment
#
# [3] Calculate Distance
# Distance between point1 (2, 1) and point2 (0, 0): 2.23606797749979

# %% [markdown]
# # **Lab4.2 Challenge**

# %%
import math
import matplotlib.pyplot as plt

def Calculat(point1,point2):
    print("\nAccess Coordinates")
    print(f"Point 1: x = {point1[0]}, y = {point1[1]}")
    print(f"Point 2: x = {point2[0]}, y = {point2[1]}")

    print("\nCalculate Distance")
    # distance = sqrt( (x2 - x1)^2 + (y2 - y1)^2 )
    distance = math.sqrt((point2[0] - point1[0]) ** 2 + (point2[1] - point1[1]) ** 2)
    print(f"Distance between point1 {point1} and point2 {point2}: {distance}")

def Plot(point1, point2):
    x = [point1[0], point2[0]]
    y = [point1[1], point2[1]]

    plt.figure(figsize=(6, 6))

    # หาช่วงแกนอัตโนมัติ
    max_value = max(
        abs(point1[0]), abs(point1[1]),
        abs(point2[0]), abs(point2[1])
    )

    # เผื่อพื้นที่รอบ ๆ และปัดเป็นเลขคู่
    limit = ((max_value + 2) // 2 + 1) * 2

    ax = plt.gca()

    # วาดเส้นและจุด
    ax.plot(x, y, marker='o', linewidth=2)

    # ชื่อจุด
    ax.text(point1[0], point1[1], " Point 1")
    ax.text(point2[0], point2[1], " Point 2")

    # กำหนดช่วงแกน
    ax.set_xlim(-limit, limit)
    ax.set_ylim(-limit, limit)

    # ตัวเลขทุก 2 หน่วย
    ax.set_xticks(range(-limit, limit + 1, 2))
    ax.set_yticks(range(-limit, limit + 1, 2))

    # Grid ทุก 1 หน่วย
    ax.set_xticks(range(-limit, limit + 1), minor=True)
    ax.set_yticks(range(-limit, limit + 1), minor=True)

    ax.grid(which='major')
    ax.grid(which='minor', linewidth=0.3)

    # ให้แกน X,Y อยู่ตรงกลาง
    ax.spines['left'].set_position('zero')
    ax.spines['bottom'].set_position('zero')
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')

    # สัดส่วนแกนเท่ากัน
    ax.set_aspect('equal')

    plt.title("Distance Between Two Points")
    plt.show()

print("--- Lab 4.2: Geometric Calculations(Challenge) ---")
while True:
    try:
        point1, point2 = None, None
        point1 = tuple(map(int, input("Point 1: (e.g., 2,3)").split(",")))
        point2 = tuple(map(int, input("Point 2: (e.g., 2,3)").split(",")))

        if len(point1) != 2 or len(point2) != 2:
            raise ValueError
        
        Calculat(point1,point2)
        Plot(point1, point2)
        break
    except ValueError as e:
        # print(e)
        print("Invalid input. Please enter coordinates in the format x,y (e.g., 2,3).")
# Out:
# --- Lab 4.2: Geometric Calculations(Challenge) ---
#
# Access Coordinates
# Point 1: x = 2, y = 4
# Point 2: x = 7, y = 0
#
# Calculate Distance
# Distance between point1 (2, 4) and point2 (7, 0): 6.4031242374328485

# %% [markdown]
# #ในส่วนของไฟล์โครงทำงานแลปในตอนนี้ หากทำครบตาม  👈 จะได้คะแนนเต็ม
#
# หากทำchallange ได้ จะได้คะแนนเพิ่มเติม และ
#
# ทำ activity ก็ได้คะแนนเพิ่มเติมเช่นกัน
